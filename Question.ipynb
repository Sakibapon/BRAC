# %% [markdown]
# #CSE474 Simulation and Modeling
# ##Brac University
# ##Summer2020
#
# ![bracu_logo.png](data:image/png;base64,...)
#
# ###Final Assessment: Theory and Lab
#
# **Format: Take Home**
#
# Instructor: Ipshita Bonhi Upoma
#
# Submission Deadline: 2nd October 2020
#
# Submission on Google Classroom

# %% [markdown]
# ##Plagiarism Policy:
#
# This is to be noted that any sort of plagiarism or assistance in cheating will be reported to the Steering Committee of Grading and Plagiarism and will be subjected to punishment (maximum punishment: suspension from the university).
#
#
# This should be also noted that the teacher can randomly ask any questions related to the answers they have submitted to validate the authenticity of the submission. Failing to explain your answers will be considered as inauthentic submission.
#
# Please, download the [Student Agreement](https://docs.google.com/document/d/1TEceqdobN1msHyHhn49HB3VGpW1vt7TKsFsdto_mrO8/edit?usp=sharing). provide your digital signature (Your FULL Name IN CAPITAL LETTER) and complete the necessary information fields, make a pdf and submit with your assignment in Google classroom. **Your Submission will not be accepted without the signed and completely filled student agreement**

# %% [markdown]
# **Submission:**
#
# Submit the .ipynb file for the following questions. Please, provide comments beside your codes to explain your work.
#
# File Name Format: StudentID_CSE474_Final

# %% [markdown]
# #Question 1 (8 Marks)
#
# ##Question 1A  (3 Marks)
# Using the scipy methods of the finite difference method, find the first derivative of the following functions
#
# > $f_{0} = 7x^{2}+ 5y^{-2} + 2z + 10$
#
# >$f_{1} = x - 2y - \frac{z}{3} + 3$
#
# >$f_{2} = x^7 - y^{5} + 7z^3 $

# %%
#Your code goes into this cell

# %% [markdown]
# # Question 1B (2 Marks)
#
# Using the results from 1A build the Jacobian for the 3 given functions above.
#
# For N number of N-dimensional equations the Jacobian Matrix is defined as
#
# > $J_{ij}(\overrightarrow{x}) = \frac{df_{i}(\overrightarrow{x})}{dx_{j}}$
#
# For a 3-dimensional case,
#
# > $J = \begin{pmatrix}\frac{df_{0}}{dx_{0}} & \frac{df_{0}}{dx_{1}} & \frac{df_{0}}{dx_{2}}\\
# \frac{df_{1}}{dx_{0}} & \frac{df_{1}}{dx_{1}} & \frac{df_{1}}{dx_{2}}\\ \frac{df_{2}}{dx_{0}} & \frac{df_{2}}{dx_{1}} & \frac{df_{2}}{dx_{2}}\\
#  \end{pmatrix}
# $

# %%
#Your code goes here

# %% [markdown]
# ##Question 1C (3 Marks)
#
# Using results the Jacobian matrix from your result in 1B, use the scipy method for Newton's Method of Root Finding for Multidimensional equations and find the roots of $f_{0}$, $f_{1}$, $f_{2}$.
#
# Newton's method for Multidimensional root finding describe each root as
# > $\overrightarrow{x}_{n+1} = \overrightarrow{x_{n}}- J^{-1}\overrightarrow{f}(\overrightarrow{x}_{n})$

# %%
#Your code goes here

# %% [markdown]
# ##Question 2 (11 Marks)
#
#
# The datatable below represents the emmission of carbon in the atmosphere for over the years.
#
# Interpolate the data using the scipy methods for linear interpolation, cubic interpolation and Lagrangian interpolation for degree 7.  Compare the plots generated from each method in the same figure.
#
# From each of the methods find the carbon emission in 2017.
#
# What is the absolute error between the result from linear and lagrangian interpolation and the error between the result from cubic and lagrangian interpolation?
#
# |  Year  | Carbon PPM |
# |--------|------------|
# |1920    |21.883
# |1925    |22.075
# |1930    |22.268
# |1935    |22.461
# |1940    |22.655
# |1945    |22.849

# %% [markdown]
# ##Question 2 (6 Marks)
# Interpolate the data using the scipy methods for linear interpolation, Lagrangian interpolation for degree 7. Compare the plots generated from each method in the same figure.  (2+2+2)

# %%
#Your code goes here

# %% [markdown]
# ##Question 2B (3 Marks)
# What is the carbon ppm in 1939 according to your lagrangian interpolation?

# %%
#Your code goes here

# %% [markdown]
# ##Question 2C (2 Marks)
#
# Suppose in 1939 the carbon ppm was 22.616 according to observation. What is the absolute error between our observed value and the value from your interpolation done in Lagrangian method.

# %%
#Your code goes here

# %% [markdown]
# #Question 3  (6 Marks)
#
# From January 1st to December 31st, The profit with respect to time for a company was following the  equation below:
# > $P = -t^{2} + 4t - 2 + e^{-3t}$
#
# Let $t_{0}$ be day 1 and $t_{f}$ be day 30.
#
# ##Question 3A
#
# Using the scipy method of trapezoid rule for integration, find the total profit from day 1 to day 30. (2)

# %%
#Your code goes here

# %% [markdown]
# ##Question 3B
# Using the scipy method of 2- Point Gaussian Quadrature for integration, find the total profit from day 1 to day 30. (2)

# %%
#Your code goes here

# %% [markdown]
# ##Question 3C
# Find the relative error of the result from trapezoid rule with respect to the 2-point Gaussian Quadrature result.  (2)

# %%
#Your code goes here

# %% [markdown]
# ##Question 4 (5 marks)
# The velocity of an object is described by the following equation
#
# > $v(t) = 4t^3 + 9t + e^{-t}$
#
# At $t_{0}$ the initial position of the object, $s=0$.
#
# By using scipy methods for Runge Kutta of order 4, find the  position of the object at t= 4.  (5)

# %%
#Your code goes here

# %% [markdown]
# #Lab (10 Marks)
#
# These are questions that require explanation of the Lab works. Write the explanations in the **Text Cells** and the additional codes if necessary for explanation, in the **Code Cells**.
#
# **In case**, you have a problem adding text explanations in a ipynb file, make one pdf with your written explanation and submit additional codes in a ipynb file.
#
# **File Naming Format:**  StudentID_CSE474_Lab_Explanation, StudentID_CSE474_Lab_AdditionalCode
#
#
# #Question A
#
# In the SIR model, explain how the contact rate per day and recovery rate per day are defined?(2)

# %% [markdown]
# **Answer:**

# %%
#Code

# %% [markdown]
# ##Question B
# If the contact rate in per day and recovery rate in per day is not known, explain how we can estimate these two parameters of the model? (2)

# %% [markdown]
# **Answer**

# %%
#Code

# %% [markdown]
# ##Question C
# Suppose you are given a fixed budget of 12000$ to handle a spread of a viral disease, in your area. The total population in your area is 90,000. You can spend the budget on awareness programs on hand washing and vaccination.Per dose of vaccine costs 120.
#
# ## Question C1
# Explain mathematically or with supporting codes, why cannot the whole budget be spent on vaccination?(3)

# %% [markdown]
# **Answer**

# %%
#Code

# %% [markdown]
# ##Question C2
# Explain mathematically or with supporting codes, how to find the optimized number of vaccinations and the amount of money to be spent on awareness campaigns. (3) **Writing the steps and explaining how it solves the problem is enough.**

# %% [markdown]
# **Answer**

# %%
#Code

# %% [markdown]
# **NB:** The SIR Model for Freshman Plague is explained in Chapter 5 and Chapter 6 Modeling and Simulation in Python by Allen B. Downey. The codes are shared in the student folder.

# %% [markdown]
# **Bonus Question 1:**
#
# Explain why defining the units in the beginning necessary for the modelling of Falling Penny. Explain the functions that calculate the change of velocity when air resistance is taken into account. (2)
#
# **NB:** The Falling Penny Myth is explained in Chapter 1 and Chapter 9 Modeling and Simulation in Python by Allen B. Downey. The codes are shared in the student folder.

# %% [markdown]
# **Answer**

# %%
#Code

# %% [markdown]
# **Bonus Question 2**:
#
# Explain the assumption the modeling of the bikesharing problem is based on. Explain the updated function which checks if no bike is available and handles the issue of negative bikes in the model. (2)
#
# **NB:** The Bike Sharing Problem is explained in Chapter 2, Modeling and Simulation in Python by Allen B. Downey. The codes are shared in the student folder.

# %% [markdown]
# **Answer**

# %%
#Code
