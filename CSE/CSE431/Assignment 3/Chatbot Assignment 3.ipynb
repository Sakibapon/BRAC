# %%
import io
import numpy as np
import random
import string #to process standard python strings
import warnings
warnings.filterwarnings('ignore')
import nltk

# %%
f=open('cse431.txt','r',errors = 'ignore')
raw=f.read()
#raw=
raw=raw.lower() # converts to lowercase
nltk.download('punkt') # first-time use only
nltk.download('wordnet') # first-time use only
sent_tokens = nltk.sent_tokenize(raw)# converts to list of sentences
word_tokens = nltk.word_tokenize(raw)# converts to list of words

sent_tokens[:2]
word_tokens[:2]
lemmer = nltk.stem.WordNetLemmatizer()

def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]
remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))  
GREETING_INPUTS = ("hello","hi","greetings","sup","what's up","hey")
GREETINGS_RESPONSES = ["Hi","Hey","*Hello there*","Hi there","Hello","I am glad! You are talking to me","Hello, How are you?"]
def greeting(sentence):

  for word in sentence.split():
    if word.lower() in GREETING_INPUTS:
      return random.choice(GREETINGS_RESPONSES)
      
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.metrics.pairwise import cosine_similarity

def response(user_response):
  chatbot_response=''
  sent_tokens.append(user_response)
  TfidfVec = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english')
  tfidf = TfidfVec.fit_transform(sent_tokens)
  vals = cosine_similarity(tfidf[-1], tfidf)
  idx = vals.argsort()[0][-2]
  flat = vals.flatten()
  flat.sort()
  req_tfidf = flat[-2]
  if(req_tfidf==0):
    chatbot_response=chatbot_response+"I am sorry! I don't understand you"
    return chatbot_response
  else:
    chatbot_response = chatbot_response+sent_tokens[idx]
    return chatbot_response
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sakib\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Sakib\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
flag=True
print("Chatbot:I am Chatbot. I will answer your queries about Chatbots. If you want to exit, type Bye!")
print("It can answer question about BRAC univesity, BRAC univesity foundation, CSE dept, CSE431, Weather,Assignment, natural language processing, Coronavirus/Covid-19 or Machine learning")
instructions='''
Some Demo Question:
Tell me about Brac University
When was Brac Univeristy Founded?
Tell me everything about BRAC University
Tell me about CSE dept
Who is taking CSE431?
what is BUX?
Who did this assignment?
Tell me about this assignment 
How many people are doing this assignment?
what is natural language processing?
What is machine learning?
What is the weather like?
Tell me about coronavirus
What is the global situation now?
Tell me about covid-19
How coronavirus spreads?
How to prevent coid-19?
What to do if I have fever?
'''
print(instructions)
while(flag==True):
    user_response = input()
    user_response=user_response.lower()
    if (user_response!='bye'):
        if (user_response=='thanks'or user_response=='thank you'):
            flag=False
            print("Chatbot: You are welcome..")
        else:
            if (greeting(user_response)!=None):
                print("Chatbot: "+greeting(user_response))
            else:
                print("Chatbot: ",end="")
                print(response(user_response))
                sent_tokens.remove(user_response)
    else:
        
        flag=False
        print("Chatbot: Bye! take care..")
'''
TasnimSakibApon_18301297
AsefHassanAmiz_16321088
RafidMostafa_16101069
SudeeptoBose_18241016
ShadmanSobhani_16301064
JebaTahsinHossain_20241066
'''
# Out:
# Chatbot:I am Chatbot. I will answer your queries about Chatbots. If you want to exit, type Bye!
# It can answer question about BRAC univesity, BRAC univesity foundation, CSE dept, CSE431, Weather,Assignment, natural language processing, Some jokes or Machine learning
#
# Some Demo Question:
# Tell me about Brac University
# When was Brac Univeristy Founded?
# Tell me everything about BRAC University
# Tell me about CSE dept
# Who is taking CSE431?
# what is BUX?
# Who did this assignment?
# Tell me about this assignment
# How many people are doing this assignment?
# what is natural language processing?
# What is machine learning?
# What is the weather like?
# Tell me about coronavirus
# What is the global situation now?
# Tell me about covid-19
# How coronavirus spreads?
#
# how to prevent coronavirus
# Chatbot: coronavirus disease (covid-19) is an infectious disease caused by a newly discovered coronavirus.
# How to prevent coid-19
# ...
